# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import acceleration

# %%
df = acceleration.df2.set_index('s')

# %%
df.plot(subplots=True, figsize=(18, 10), layout=(2, 3))
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x7f55245e89e8>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x7f55244cc160>]], dtype=object)

# %%
df
# Out:
#             v            d          t
# s
# 0           0            0          0
# 1         100         0.01       0.01
# 2     166.667        0.006      0.016
# 3     214.286   0.00466667  0.0206667
# 4     253.247   0.00394872  0.0246154
# 5     287.013   0.00348416  0.0280995
# 6     317.225   0.00315234  0.0312519
# 7      344.81   0.00290015   0.034152
# 8     370.351   0.00270014  0.0368522
# 9     394.245    0.0025365  0.0393887
# 10    416.773   0.00239939  0.0417881
# 11    438.146   0.00228234  0.0440704
# 12    458.525   0.00218091  0.0462513
# 13    478.037   0.00209189  0.0483432
# 14    496.783   0.00201295  0.0503562
# 15    514.848   0.00194232  0.0522985
# 16      532.3   0.00187864  0.0541771
# 17    549.199   0.00182083  0.0559979
# 18    565.593   0.00176806   0.057766
# 19    581.525   0.00171962  0.0594856
# 20    597.032   0.00167495  0.0611606
# 21    612.147   0.00163359  0.0627942
# 22    626.898   0.00159516  0.0643893
# ...
